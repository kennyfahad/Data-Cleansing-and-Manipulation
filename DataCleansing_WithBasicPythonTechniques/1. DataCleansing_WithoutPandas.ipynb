# %% [markdown]
# # Importing Library

# %%
import csv

# %% [markdown]
# # About Artworks Data
#
# ## Museum of Modern Art Collection
# The Museum of Modern Art (MoMA) acquired its first artworks in 1929, the year it was established. Today, the Museum’s evolving collection contains almost 200,000 works from around the world spanning the last 150 years. The collection includes an ever-expanding range of visual expression, including painting, sculpture, printmaking, drawing, photography, architecture, design, film, and media and performance art.
#
# MoMA is committed to helping everyone understand, enjoy, and use our collection. The Museum’s website features 72,706 artworks from 20,956 artists. The artworks dataset contains 130,262 records, representing all of the works that have been accessioned into MoMA’s collection and cataloged in our database. It includes basic metadata for each work, including title, artist, date, medium, dimensions, and date acquired by the Museum. Some of these records have incomplete information and are noted as “not curator approved.”
#
# The follwoing work is down on the artiest dataset which contains 16,730 records, representing all the artists who have work in MoMA's collection and have been cataloged in MOMA's database. The dataset includes information about 'Title', 'Artist', 'Nationality', 'BeginDate', 'EndDate', 'Gender', 'Date' and 'Department'. It has been already enhanced from the dataset shared by MOMA which included basic metadata for each artist, including name, nationality, gender, birth year, and death year.
#
# https://www.kaggle.com/datasets/momanyc/museum-collection?resource=download

# %% [markdown]
# # Loading Data

# %%
f = open("data.csv", encoding = "utf-8")

data = csv.reader(f)

# %%
moma = list(data)
len(moma)
# Out:
# 16730

# %%
headers = moma[0]
print(headers)
# Out:
# ['Title', 'Artist', 'Nationality', 'BeginDate', 'EndDate', 'Gender', 'Date', 'Department']

# %%
artworks = moma[1:]

# %% [markdown]
# ### Getting Departments

# %%
depts = []

for row in artworks:
    dept = row[-1]
    depts.append(dept)

# %%
len(depts)
# Out:
# 16729

# %%
unq_depts = list(set(depts))

# %%
print(unq_depts)
# Out:
# ['Photography', 'Drawings', 'Painting & Sculpture', 'Media and Performance Art', 'Fluxus Collection', 'Architecture & Design', 'Prints & Illustrated Books', 'Film']

# %%
len(unq_depts)
# Out:
# 8

# %% [markdown]
# ### Getting Nationality and Gender of Artists

# %%
print(artworks[:3])
# Out:
# [['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', '(American)', '(1947)', '(2013)', '(Female)', '1986', 'Prints & Illustrated Books'], ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', '(Spanish)', '(1916)', '(2007)', '(Male)', '1978', 'Prints & Illustrated Books'], ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', '(French)', '(1870)', '(1943)', '(Male)', '1889-1911', 'Prints & Illustrated Books']]

# %%
for row in artworks:
    row[2] = row[2].replace("(","").replace(")","")
    row[-3] = row[-3].replace("(","").replace(")","")

# %%
print(artworks[:3])
# Out:
# [['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', '(1947)', '(2013)', 'Female', '1986', 'Prints & Illustrated Books'], ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', '(1916)', '(2007)', 'Male', '1978', 'Prints & Illustrated Books'], ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', '(1870)', '(1943)', 'Male', '1889-1911', 'Prints & Illustrated Books']]

# %%
# checking for missing nationalities information
counts = 0
for row in artworks:
    
    if row[2] == "":
        counts+=1

print(f"{counts} Nationality records are missing")
# Out:
# 494 Nationality records are missing

# %%
# checking for missing gender information
counts = 0
for row in artworks:
    
    if row[-3] == "":
        counts+=1
print(f"{counts} Gender records are missing")
# Out:
# 794 Gender records are missing

# %%
# filling missing values
for row in artworks:
    if row[2] == "":
        row[2] = row[2].replace("", "Nationality Unknown")
    if row[-3] == "":
        row[-3] = row[-3].replace("", "Gender Unknown")

# %% [markdown]
# ### Standardizing Date

# %%
# the function converts years in dataset
def convert_date(date):
    if date != "":
        date = date.replace("(","").replace(")","")
        date = int(date)
    return date

# %%
for row in artworks:
    row[3] = convert_date(row[3])
    row[4] = convert_date(row[4])

# %%
print(artworks[:3])
# Out:
# [['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', 1947, 2013, 'Female', '1986', 'Prints & Illustrated Books'], ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', 1916, 2007, 'Male', '1978', 'Prints & Illustrated Books'], ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', 1870, 1943, 'Male', '1889-1911', 'Prints & Illustrated Books']]

# %% [markdown]
# #### The dataset also contains dates which do not follow conventions

# %%
sub_dat = []

for row in artworks:
    sub_dat.append(row[-2])
    
unq_sub = list(set(sub_dat))

# %%
unq_sub = list(set(sub_dat))
len(unq_sub)
# Out:
# 1154

# %%
print(unq_sub)
# Out:
# ['1994', 'c. 1964-1965', '1914-1942', '1949-1952', '1900-1944', '1900-1938', '(1952)', '(c. 1972)', '1896', '(1903)', '(1902)', '(2007-2008)', '1878', '1974-1977', '1911-1931', '1996-1997', '1897-1902', '(1913)', '(c .1981)', '1936-1941', '1943-1944', 'c. 1909-1910', '1974-1975', '1970-1973', '1855', '1900-1936', '1945-1946', '1920-1922', '1964', 'c. 1962-1963', 'c. 1911', 'c.1941', 'c. 1855-1860', '1932-1958', 'c. 1979', '1990-1991', 'c. 1907', '1941', '1837-1852', '(c. 1917)', '1914-1916', 'c. 1927-1930', 'c. 1920-1924', '1901', '1877', '1906', '1885', '(1929)', '1930-1931', 'c. 1880', '1919-1923', '1949', '1997-2003', '2000', '1967', 'c. 1940', '(1916)', '1866', '1985-1987', '2002-2003', '1961-1962', '1908-1950', '1895-1900', '(1935)', 'c. 1930', '1974-1984', '(1922-1923)', '1969', '(1974-1975)', '(1971-1973)', '(1986)', '1923-1948', '1972-1973', '1908-1924', '1958-1965', '1948-1950', '1912-1927', '(1917-1918)', '1938-1959', '(1999)', '(1957)', '1947-1953', 'c. 1969-1970', '1998', '1920-1930', '1927-1952', '1953-1954', '1973-1978', 'c. 1998', 'c.1946', 'c. 1951-1952', '1954-1955', '(1922)', '(1949-1950)', 'c. 1980', '1939-1943', '1947-1958', '1923-1928', 'c.1981', '(1969)', 'c. 1969', '1952-1954', '1906-1912', '(1977-1979)', '1964-1965', 'c. 2003', 'c.1953', '1996', '1952-1953', '1912-1926', '1943-1981', '1880', '1920s', '1961', '1940', 'c. 1960-1961', '2018', '(c. 1938)', '(c. 1917-1919)', '1947-1964', '(1992)', 'c.1895', '1911-1914', '1962-1983', '1905', '1934', '1998 - 2004', '1930-1935', 'c. 1916-1918', '(2004)', '1993-1994', '1965-1968', '(1953)', '1995-2002', '2015', '(c. 1927)', 'c. 1933', '1929-1931', '1900-1943', '1954', '1946-1972', '(1923)', '1998-2008', '1888', 'c. 1965-1966', 'c. 1921-1923', '(c. 1932)', '(1963)', '1923-1952', '1959-1964', '1971-1975', '1916-1923', '1976-1979', '1998-2014', '1957-1960', '(1932)', '1893-1903', '1970-1972', '1995-2003', '1852-1857', 'c.1995', '1936-1938', '1881', '1970-1975', 'c. 1948', '1931-1932', '1942-1944', '(1901)', '2000-2001', '1949-1950', '1910', '1928', 'c. 1938', '1884-1886', '1962-1966', '2009', '(1921-1922)', '(1962-1975)', '1980', 'c. 1950s', '1968-1970', '1959-1967', '1962-1968', '1950-1951', '1908', '1963-1966', '2004-2005', '1946', '1880-1910', '2012', '(1966)', 'c. 1959', '1931', '1868', 'c. 1920', 'c. 1939-1940', 'c. 1904-1912', '1931-1933', '1913-1921', 'c. 1976', '(2000)', 'c. 1895', '1948-1981', '1963-2003', '1944-1945', '1870-1879', '1964-1967', '(c. 1914-1920)', '(c. 1983-1985)', '1826-1896', 'c. 1970', '1915-1917', '1929-1932', '1900-1949', '1896-1897', '1899-1900', '1982-1984', '1937', "c. 1920's", '1986-1987', 'c. 1858', '(c. 1896)', '1915-1922', '1967-1988', '1902-1904', '1961-c. 1965', '(c. 1936)', '1896-1906', '1914-1918', '1860', '2003-2005', '1984', '1927-1937', '(c. 1900-1910)', '1950', 'c.1947', 'c.1925-1928', '1961-1969', 'c. 1956', '1858', '1946-1949', '1937-1939', '(1940)', '1974-1980', '1890', '1967-1998', '1906-1907', '(1930-1932)', '1955', '2000-2003', '1919-1959', '1953', '(c. 1915)', '1855-1856', '1922-1923', '2003-2009', '(1927)', '(1998-1999)', '1968-1972', 'c. 1957', '1925', '1863', '1927-1931', 'c. 1931', '1904-1905', '(c. 1880)', '1971', '1943', '1914-1925', '1919-1958', '1927-1930', '1971-1973', '1943-1953', '(c. 1920)', '1890s', '(1928)', '1891', 'c. 1958', '1955-1956', '1895-1898', '1943-1959', '1928-1939', '(1971)', 'c. 1904-1907', '1900-1947', '1954-1958', '1980-1985', '1998-2009', '(c. 1969-1973)', '1990-1997', '1992-1993', '1928-1930', '1850', '1920-1933', '1998-1999', '1864-1865', '(1897)', '1973-1976', '1944-1965', '(1981-1982)', '1858-1870', 'c. 1870', '(c. 1937)', 'c. 1921', '1956-1957', '1942', '1871', '(c. 1975)', 'c.1901', 'c.1930s', '(1910-1911)', 'c. 1924', 'c. 1990', '1969-1971', '1893-1894', '1904', '1933', '1932-1934', '1978-1981', 'c. 1923-1924', '1926-1927', '1901-1902', '(c. 1910s-30s)', '1954-1957', '1977-1978', '1935-1958', '1899', '1991-2012', '1995-1999', '1909', '1900-1958', '1969-1972', '1872-1927', '1882' ...

# %% [markdown]
# #### Removing unwanted Characters

# %%
bad_chr = ["(",")", "c", "C", ".", "'", "s", " "]


def demise(date):
    for c in bad_chr:
        date = date.replace(c,"")
    return date

# %%
for row in artworks:
    row[-2] = demise(row[-2])

# %%
sub_dat = []

for row in artworks:
    sub_dat.append(row[-2])

# %%
unq_sub = list(set(sub_dat))

# %%
len(unq_sub)
# Out:
# 742

# %%
print(unq_sub)
# Out:
1999', '1979-1980', '1898', '2003', '1931-1967', '1939-1945', '1930-1933', '1962-1964', '1978-1984', '1965', '1973', '1856', '1816-1904', '1941-1945', '1869-1875', '1989-1991', '1900-1952', '1959', '1980-1984', '1926-1930', '1952-1968', '1924-1929', '1989-1994', '1919-1925', '2001-2004', '1983', '1900-1950', '1916', '1968', '1888-1895', '1966-1975', '1975', '1930-1941', '1913-1914', '2007', '1851', '1860-1870', '1893-1896', '1940-1954', '1958-1964', '1853', '1937-1938', '1999-2001', '1915-1919', '1914-1917', '1843-1848', '1941-1944', '2001-2003', '1942-1943', '1936', '1889-1911', '1926-1938', '1934-1951', '1916-1918', '1840-1851', '1874', '1968-1977', '1990-1992', '1926-1932', '1994-1996', '1927-1943', '2005-2007', '1900-1904', '1919-1922', '1948-1949', '1968-1974', '1980-1983', '1865-1875', '1873', '1938', '1886', '1919-1921', '1967-1975', '1933-1934', '18 ...

# %% [markdown]
# #### Taking average of dates in '1932-1966' format

# %%
for row in artworks:
    if "-" in row[-2]:
        splt = row[-2].split("-")
        f = int(splt[0])
        s = int(splt[1])
        avg = (f+s)/2
        avg = int(avg)
        row[-2] = avg
    else:
        row[-2] = int(row[-2])

# %%
sub_dat = []

for row in artworks:
    sub_dat.append(row[-2])

# %%
unq_sub = list(set(sub_dat))

# %%
len(unq_sub)
# Out:
# 182

# %%
print(unq_sub)
# Out:
# [1798, 1805, 970, 1886, 1811, 1818, 1826, 1832, 1836, 1837, 1840, 1844, 1845, 1846, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1880, 1881, 1882, 1883, 1884, 1885, 985, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

# %% [markdown]
# # Cleaned data

# %%
print(artworks[:3])
# Out:
# [['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', 1947, 2013, 'Female', 1986, 'Prints & Illustrated Books'], ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', 1916, 2007, 'Male', 1978, 'Prints & Illustrated Books'], ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', 1870, 1943, 'Male', 1900, 'Prints & Illustrated Books']]

# %%
f = open("artists_updated.csv","w", encoding = "utf-8", newline = "")

# %%
writer = csv.writer(f, delimiter = ",")

# %%
writer.writerow(headers)

for row in artworks:
    writer.writerow(row)
